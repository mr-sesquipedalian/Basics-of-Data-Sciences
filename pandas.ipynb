# %%
import numpy as np
r=[]
for line in open("data_2d.csv"):
    row=line.split(',')
    sample=list(map(float,row))
    r.append(sample)
r
# Out:
# [[17.9302012052, 94.5205919533, 320.259529602],
#  [97.1446971852, 69.5932819844, 404.634471526],
#  [81.7759007845, 5.73764809688, 181.485107741],
#  [55.8543424175, 70.3259016768, 321.773638018],
#  [49.3665499855, 75.1140401571, 322.465485583],
#  [3.19270246506, 29.2562988631, 94.6188108954],
#  [49.2007840582, 86.1444385075, 356.348092747],
#  [21.882803904, 46.8415051959, 181.653769226],
#  [79.5098627219, 87.397355535, 423.557743194],
#  [88.1538874975, 65.2056419279, 369.229245443],
#  [60.7438543399, 99.9576339008, 427.605803661],
#  [67.4155819451, 50.3683096094, 292.471821553],
#  [48.3181157719, 99.1289531425, 395.529811407],
#  [28.8299719729, 87.1849488537, 319.031348455],
#  [43.853742664, 64.4736390798, 287.4281441],
#  [25.3136940868, 83.5452942552, 292.768908839],
#  [10.807726675, 45.6955685904, 159.663307674],
#  [98.365745882, 82.6973935253, 438.798963866],
#  [29.1469099692, 66.3651067611, 250.986309034],
#  [65.1003018959, 33.3538834975, 231.711507921],
# ...

# %%
r=np.array(r)
r.shape
# Out:
# (100, 3)

# %%
import pandas as pd
x=pd.read_csv("data_2d.csv",header=None)

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
# 0    100 non-null float64
# 1    100 non-null float64
# 2    100 non-null float64
# dtypes: float64(3)
# memory usage: 2.4 KB

# %%
x.head()
# Out:
#            0          1           2
# 0  17.930201  94.520592  320.259530
# 1  97.144697  69.593282  404.634472
# 2  81.775901   5.737648  181.485108
# 3  55.854342  70.325902  321.773638
# 4  49.366550  75.114040  322.465486

# %%
x.head(10)
# Out:
#            0          1           2
# 0  17.930201  94.520592  320.259530
# 1  97.144697  69.593282  404.634472
# 2  81.775901   5.737648  181.485108
# 3  55.854342  70.325902  321.773638
# 4  49.366550  75.114040  322.465486
# 5   3.192702  29.256299   94.618811
# 6  49.200784  86.144439  356.348093
# 7  21.882804  46.841505  181.653769
# 8  79.509863  87.397356  423.557743
# 9  88.153887  65.205642  369.229245

# %%
m=x.as_matrix()
# Out:
# c:\users\apoorav gupta\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.

# %%
type(m)
# Out:
# numpy.ndarray

# %%
m[0]
# Out:
# array([ 17.93020121,  94.52059195, 320.2595296 ])

# %%
x[0]
# Out:
# 0     17.930201
# 1     97.144697
# 2     81.775901
# 3     55.854342
# 4     49.366550
# 5      3.192702
# 6     49.200784
# 7     21.882804
# 8     79.509863
# 9     88.153887
# 10    60.743854
# 11    67.415582
# 12    48.318116
# 13    28.829972
# 14    43.853743
# 15    25.313694
# 16    10.807727
# 17    98.365746
# 18    29.146910
# 19    65.100302
# 20    24.644113
# 21    37.559805
# 22    88.164506
# 23    13.834621
# 24    64.410844
# 25    68.925992
# 26    39.488442
# 27    52.463178
# 28    48.484787
# 29     8.062088
#         ...
# 70    30.187692
# 71    11.788418
# 72    18.292424
# 73    96.712668
# 74    31.012739
# 75    11.397261
# 76    17.392556
# 77    72.182694
# 78    73.980021
# 79    94.493058
# 80    84.562821
# 81    51.742474
# 82    53.748590
# 83    85.050835
# 84    46.777250
# 85    49.758434
# 86    24.119257
# 87    27.201576
# 88     7.009596
# 89    97.646950
# 90     1.382983
# 91    22.323530
# 92    45.045406
# 93    40.163991
# ...

# %%
type(x[0])
# Out:
# pandas.core.series.Series

# %%
x.iloc[0]
# Out:
# 0     17.930201
# 1     94.520592
# 2    320.259530
# Name: 0, dtype: float64

# %%
x.loc[0]
# Out:
# 0     17.930201
# 1     94.520592
# 2    320.259530
# Name: 0, dtype: float64

# %%
x.ix[0]
# Out:
# c:\users\apoorav gupta\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 0     17.930201
# 1     94.520592
# 2    320.259530
# Name: 0, dtype: float64

# %%
x[[0,2]]
# Out:
#             0           2
# 0   17.930201  320.259530
# 1   97.144697  404.634472
# 2   81.775901  181.485108
# 3   55.854342  321.773638
# 4   49.366550  322.465486
# 5    3.192702   94.618811
# 6   49.200784  356.348093
# 7   21.882804  181.653769
# 8   79.509863  423.557743
# 9   88.153887  369.229245
# 10  60.743854  427.605804
# 11  67.415582  292.471822
# 12  48.318116  395.529811
# 13  28.829972  319.031348
# 14  43.853743  287.428144
# 15  25.313694  292.768909
# 16  10.807727  159.663308
# 17  98.365746  438.798964
# 18  29.146910  250.986309
# 19  65.100302  231.711508
# 20  24.644113  163.398161
# 21  37.559805   83.480155
# 22  88.164506  466.265806
# 23  13.834621  100.886430
# 24  64.410844  365.641048
# 25  68.925992  426.140015
# 26  39.488442  235.532389
# 27  52.463178  283.291640
# 28  48.484787  298.581440
# 29   8.062088  309.234109
# ..        ...         ...
# 70  30.187692   89.539008
# 71  11.788418  181.550683
# 72  18.292424  224.773383
# ...

# %%
f=pd.read_csv("data_2d.csv", header=None)
f[f[0]<5]
# Out:
#            0          1           2
# 5   3.192702  29.256299   94.618811
# 44  3.593966  96.252217  293.237183
# 54  4.593463  46.335932  145.818745
# 90  1.382983  84.944087  252.905653
# 99  4.142669  52.254726  168.034401

# %%
x[0]<5    #it actually checks boolean objects
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# 29    True
#       ...
# 70    True
# 71    True
# 72    True
# 73    True
# 74    True
# 75    True
# 76    True
# 77    True
# 78    True
# 79    True
# 80    True
# 81    True
# 82    True
# 83    True
# 84    True
# 85    True
# 86    True
# 87    True
# 88    True
# 89    True
# 90    True
# 91    True
# 92    True
# 93    True
# 94    True
# 95    True
# 96    True
# 97    True
# 98    True
# 99    True
# Name: 0, Length: 100, dtype: bool

# %%
type(x[0]<5)
# Out:
# pandas.core.series.Series

# %%
p=pd.read_csv("airline\international-airline-passengers.csv", engine="python", skipfooter=3)

# %%
p.columns
# Out:
# Index(['Month', 'International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60'], dtype='object')

# %%
p.columns=["Months","Passengers"]

# %%
t=p.columns

# %%
t
# Out:
# Index(['Months', 'Passengers'], dtype='object')

# %%
p['Passengers']
# Out:
# 0      112
# 1      118
# 2      132
# 3      129
# 4      121
# 5      135
# 6      148
# 7      148
# 8      136
# 9      119
# 10     104
# 11     118
# 12     115
# 13     126
# 14     141
# 15     135
# 16     125
# 17     149
# 18     170
# 19     170
# 20     158
# 21     133
# 22     114
# 23     140
# 24     145
# 25     150
# 26     178
# 27     163
# 28     172
# 29     178
#       ...
# 114    491
# 115    505
# 116    404
# 117    359
# 118    310
# 119    337
# 120    360
# 121    342
# 122    406
# 123    396
# 124    420
# 125    472
# 126    548
# 127    559
# 128    463
# 129    407
# 130    362
# 131    405
# 132    417
# 133    391
# 134    419
# 135    461
# 136    472
# 137    535
# 138    622
# 139    606
# 140    508
# 141    461
# 142    390
# 143    432
# Name: Passengers, Length: 144, dtype: int64

# %%
p['ones']=1
p.head()
# Out:
#     Months  Passengers  ones
# 0  1949-01         112     1
# 1  1949-02         118     1
# 2  1949-03         132     1
# 3  1949-04         129     1
# 4  1949-05         121     1

# %% [markdown]
# ### Apply() function

# %%
from datetime import datetime

# %%
datetime.strptime("1949-05","%Y-%m")
# Out:
# datetime.datetime(1949, 5, 1, 0, 0)

# %%
p.head()
# Out:
#     Months  Passengers  ones
# 0  1949-01         112     1
# 1  1949-02         118     1
# 2  1949-03         132     1
# 3  1949-04         129     1
# 4  1949-05         121     1

# %%
p['dt']=p.apply(lambda row: datetime.strptime(row['Months'],"%Y-%m"),axis=1)
p
# Out:
#       Months  Passengers  ones         dt
# 0    1949-01         112     1 1949-01-01
# 1    1949-02         118     1 1949-02-01
# 2    1949-03         132     1 1949-03-01
# 3    1949-04         129     1 1949-04-01
# 4    1949-05         121     1 1949-05-01
# 5    1949-06         135     1 1949-06-01
# 6    1949-07         148     1 1949-07-01
# 7    1949-08         148     1 1949-08-01
# 8    1949-09         136     1 1949-09-01
# 9    1949-10         119     1 1949-10-01
# 10   1949-11         104     1 1949-11-01
# 11   1949-12         118     1 1949-12-01
# 12   1950-01         115     1 1950-01-01
# 13   1950-02         126     1 1950-02-01
# 14   1950-03         141     1 1950-03-01
# 15   1950-04         135     1 1950-04-01
# 16   1950-05         125     1 1950-05-01
# 17   1950-06         149     1 1950-06-01
# 18   1950-07         170     1 1950-07-01
# 19   1950-08         170     1 1950-08-01
# 20   1950-09         158     1 1950-09-01
# ...

# %% [markdown]
# ### join

# %%
t1=pd.read_csv("table1.csv")
t2=pd.read_csv("table2.csv")

# %%
t1
# Out:
#    user_id            email  age
# 0        1  alice@gmail.com   20
# 1        2    bob@gmail.com   25
# 2        3  carol@gmail.com   30

# %%
t2
# Out:
#     user_id  ad_id  click
# 0         1      1      1
# 1         1      2      0
# 2         1      5      0
# 3         2      3      0
# 4         2      4      1
# 5         2      1      0
# 6         3      2      0
# 7         3      1      0
# 8         3      3      0
# 9         3      4      0
# 10        3      5      1

# %%
m=pd.merge(t1,t2)

# %%
m
# Out:
#     user_id            email  age  ad_id  click
# 0         1  alice@gmail.com   20      1      1
# 1         1  alice@gmail.com   20      2      0
# 2         1  alice@gmail.com   20      5      0
# 3         2    bob@gmail.com   25      3      0
# 4         2    bob@gmail.com   25      4      1
# 5         2    bob@gmail.com   25      1      0
# 6         3  carol@gmail.com   30      2      0
# 7         3  carol@gmail.com   30      1      0
# 8         3  carol@gmail.com   30      3      0
# 9         3  carol@gmail.com   30      4      0
# 10        3  carol@gmail.com   30      5      1

# %%
t1.merge(t2,on="user_id")
# Out:
#     user_id            email  age  ad_id  click
# 0         1  alice@gmail.com   20      1      1
# 1         1  alice@gmail.com   20      2      0
# 2         1  alice@gmail.com   20      5      0
# 3         2    bob@gmail.com   25      3      0
# 4         2    bob@gmail.com   25      4      1
# 5         2    bob@gmail.com   25      1      0
# 6         3  carol@gmail.com   30      2      0
# 7         3  carol@gmail.com   30      1      0
# 8         3  carol@gmail.com   30      3      0
# 9         3  carol@gmail.com   30      4      0
# 10        3  carol@gmail.com   30      5      1

# %% [markdown]
# ### .values vs .as_matrix()

# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame([[1,2],[3,4]])
df
# Out:
#    0  1
# 0  1  2
# 1  3  4

# %%
df.as_matrix()
# Out:
# c:\users\apoorav gupta\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.
# array([[1, 2],
#        [3, 4]], dtype=int64)

# %%
df.values
# Out:
# array([[1, 2],
#        [3, 4]], dtype=int64)
